# %% [markdown]
# The purpose of this document is to explore the collected wind forecast data for preliminary analysis

# %%
import pandas as pd
df = pd.read_csv('/Users/schristianson/Desktop/NY Wind Energy Model/historicalForecast10km2024/historicalForecast10km01.csv')

data = pd.DataFrame()

#Get all data points for the first location at 80m
columns = df.columns.tolist()

for i in range(1,13):
    df = pd.read_csv(f'/Users/schristianson/Desktop/NY Wind Energy Model/historicalForecast10km2024/historicalForecast10km{i:02}.csv')
    data = pd.concat([data, df[columns[0:3]]], axis=0)

data['Date'] = data['Date'].apply(lambda x: x if " " in x else x + " 00:00:00")
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

print(data.head())
# Out:
# (721, 1337)
#                      u80_(42.51093456200011, -76.47950663544776)  \
# Date
# 2024-01-01 00:00:00                                     0.874212
# 2024-01-01 01:00:00                                     0.098759
# 2024-01-01 02:00:00                                     1.915742
# 2024-01-01 03:00:00                                     1.259196
# 2024-01-01 04:00:00                                     0.870409
#
#                      v80_(42.51093456200011, -76.47950663544776)
# Date
# 2024-01-01 00:00:00                                    -0.600637
# 2024-01-01 01:00:00                                    -0.155481
# 2024-01-01 02:00:00                                    -0.474802
# 2024-01-01 03:00:00                                    -0.993299
# 2024-01-01 04:00:00                                    -1.945385

# %%
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

data['Wind Speed'] = data.apply(lambda row: np.sqrt((row**2).sum()), axis=1)
data['Wind Speed Sqrt'] = data['Wind Speed'].apply(np.sqrt)

plt.figure(figsize=(12, 6))
sns.lineplot(data, x = 'Date', y ='Wind Speed')
plt.show()

plt.figure(figsize = (12,6))
sns.lineplot(data, x='Date', y = 'Wind Speed Sqrt')
plt.show()

# %%
#Get the mean of each wind speed component across the whole year for each location
import numpy as np

data = pd.DataFrame()

for i in range(1,13):
    df = pd.read_csv(f'/Users/schristianson/Desktop/NY Wind Energy Model/historicalForecast10km2024/historicalForecast10km{i:02}.csv')
    df['Date'] = df['Date'].apply(lambda x: x if " " in x else x + " 00:00:00")
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)
    
    data = pd.concat([data, df[[col for col in df.columns if '80' in col]]], axis=0)

meanSpeed = np.array(data.apply(np.mean, axis=0))
df_mean = pd.DataFrame([meanSpeed], columns = data.columns)

# %%
#Get the mean wind speed across the whole year for each location
import numpy as np

data = pd.DataFrame()

for i in range(1,13):
    df = pd.read_csv(f'/Users/schristianson/Desktop/NY Wind Energy Model/historicalForecast10km2024/historicalForecast10km{i:02}.csv')
    df['Date'] = df['Date'].apply(lambda x: x if " " in x else x + " 00:00:00")
    df['Date'] = pd.to_datetime(df['Date'])
    df.set_index('Date', inplace=True)
    
    data = pd.concat([data, df[[col for col in df.columns if '80' in col]]], axis=0)

data_coords = set()
for col in df_mean.columns:
    coord = col.split("_")[1]
    data_coords.add(coord)

df_mag = pd.DataFrame(index=data.index)
new_cols = {}

data_coords = list(data_coords)
for coord in data_coords:
    matching_cols = [col for col in df_mean.columns if str(coord) in col]
    df_selected = data[matching_cols]
    new_cols[str(coord)] = np.sqrt((df_selected ** 2).sum(axis=1))

new_df = pd.DataFrame(new_cols)
df_mag = pd.concat([df_mag, new_df], axis=1)

meanSpeedMag = np.array(df_mag.apply(np.mean, axis=0))
df_meanMag = pd.DataFrame([meanSpeedMag], columns = df_mag.columns)

# %%
#Plot correlation across NY State
import geopandas as gpd
from makeNYGrid import makeNYGrid
from shapely.geometry import Polygon, Point
import matplotlib.pyplot as plt
from cartopy import crs as ccrs, feature as cfeature
import cartopy.io.shapereader as shpreader
from cartopy.feature import ShapelyFeature
from shapely.geometry import box
from cartopy.io.img_tiles import Stamen
import pandas as pd

grid_gdf, centers_gdf, coords_list = makeNYGrid()

#Get NY State Geometry
url = "/Users/schristianson/Desktop/NY Wind Energy Model/ne_10m_admin_1_states_provinces/ne_10m_admin_1_states_provinces.shp"
gdf = gpd.read_file(url)

# Filter for New York
ny_state = gdf[gdf['name'] == 'New York']

ny_geometry = ny_state.geometry.iloc[0]

map_extent = [-80, -71.5, 40, 46]
map_box = box(*map_extent)  # A rectangle covering the map extent

# Subtract the shape geometry from the full extent
mask_geometry = map_box.difference(ny_geometry)

# Create a map with a PlateCarree projection
fig, ax = plt.subplots(figsize=(30, 14), subplot_kw={'projection': ccrs.PlateCarree()})

# Set the extent to the mainland U.S.
ax.set_extent(map_extent, crs=ccrs.PlateCarree())

us_feature = ShapelyFeature([ny_geometry], ccrs.PlateCarree(), facecolor='lightgray', linewidth=0.3,)
ax.add_feature(us_feature)

for geom in grid_gdf.geometry:
    geom = geom.intersection(ny_geometry)
    feature = ShapelyFeature([geom], ccrs.PlateCarree(), edgecolor="black", facecolor='white', linewidth=0.2)
    ax.add_feature(feature)

# %%
grid_gdf, centers_gdf, coords_list = makeNYGrid()

#Get NY State Geometry
url = "/Users/schristianson/Desktop/NY Wind Energy Model/ne_10m_admin_1_states_provinces/ne_10m_admin_1_states_provinces.shp"
gdf = gpd.read_file(url)

# Filter for New York
ny_state = gdf[gdf['name'] == 'New York']

ny_geometry = ny_state.geometry.iloc[0]

map_extent = [-81, -71.5, 40, 46]
map_box = box(*map_extent)  # A rectangle covering the map extent

# Subtract the shape geometry from the full extent
mask_geometry = map_box.difference(ny_geometry)

# Create a map with a PlateCarree projection
fig, ax = plt.subplots(figsize=(30, 14), subplot_kw={'projection': ccrs.PlateCarree()})

# Set the extent to the mainland U.S.
ax.set_extent(map_extent, crs=ccrs.PlateCarree())

us_feature = ShapelyFeature([ny_geometry], ccrs.PlateCarree(), facecolor='lightgray', linewidth=0.3,)
ax.add_feature(us_feature)

#load wind turbines
#df = pd.read_csv("/Users/schristianson/Desktop/NY Wind Energy Model/uswtdb_v7_2_20241120.csv")
df = pd.read_csv("/Users/schristianson/Desktop/NY Wind Energy Model/uswtdb_V8_0_20250225.csv")

# Filter for New York State (NY)
df_ny = df[df["t_state"] == "NY"]

# Select only coordinates
ny_turbine_coords = list(zip(df_ny["ylat"], df_ny["xlong"]))

for coord in ny_turbine_coords:
    lat, lon = coord
    ax.plot(lon, lat, marker='o', color='red', markersize=6, transform=ccrs.PlateCarree())

plt.show()

# %%
import seaborn as sns
import pandas as pd

df_energy = pd.read_csv('/Users/schristianson/Desktop/NY Wind Energy Model/historical_energy.csv')
print(df_energy.head())
print(df_energy.dtypes)

sns.lineplot(df_energy, y='Megawatthours')
# Out:
#    Unnamed: 0            period  Megawatthours
# 0           0  2018-12-31T19-05          950.0
# 1           1  2018-12-31T20-05          940.0
# 2           2  2018-12-31T21-05         1074.0
# 3           3  2018-12-31T22-05         1149.0
# 4           4  2018-12-31T23-05         1214.0
# Unnamed: 0         int64
# period            object
# Megawatthours    float64
# dtype: object
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 8
#       5 print(df_energy.head())
#       6 print(df_energy.dtypes)
# ----> 8 sns.lineplot(df_energy, x='period', y='Megawatthours')
#
# File /opt/anaconda3/envs/windForecast/lib/python3.10/site-packages/seaborn/relational.py:515, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     512 color = kwargs.pop("color", kwargs.pop("c", None))
#     513 kwargs["color"] = _default_color(ax.plot, hue, color, kwargs)
# --> 515 p.plot(ax, kwargs)
#     516 return ax
#
# File /opt/anaconda3/envs/windForecast/lib/python3.10/site-packages/seaborn/relational.py:372, in _LinePlotter.plot(self, ax, kws)
#     369                     obj.set_capstyle(line_capstyle)
#     371 # Finalize the axes details
# --> 372 self._add_axis_labels(ax)
#     373 if self.legend:
#     374     legend_artist = partial(mpl.lines.Line2D, xdata=[], ydata=[])
#
# File /opt/anaconda3/envs/windForecast/lib/python3.10/site-packages/seaborn/_base.py:1196, in VectorPlotter._add_axis_labels(self, ax, default_x, default_y)
#    1191 # TODO ax could default to None and use attached axes if present
#    1192 # but what to do about the case of facets? Currently using FacetGrid's
#    1193 # set_axis_labels method, which doesn't add labels to the interior even
#    1194 # when the axes are not shared. Maybe that makes sense?
#    1195 if not ax.get_xlabel():
# -> 1196     x_visible = any(t.get_visible() for t in ax.get_xticklabels())
#    1197     ax.set_xlabel(self.variables.get("x", default_x), visible=x_visible)
#    1198 if not ax.get_ylabel():
#
# File /opt/anaconda3/envs/windForecast/lib/python3.10/site-packages/matplotlib/axes/_base.py:74, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      73 def wrapper(self, *args, **kwargs):
# ---> 74     return get_method(self)(*args, **kwargs)
#
# File /opt/anaconda3/envs/windForecast/lib/python3.10/site-packages/matplotlib/axis.py:1508, in Axis.get_ticklabels(self, minor, which)
#    1506 if minor:
#    1507     return self.get_minorticklabels()
# -> 1508 return self.get_majorticklabels()
#
# File /opt/anaconda3/envs/windForecast/lib/python3.10/site-packages/matplotlib/axis.py:1465, in Axis.get_majorticklabels(self)
#    1463 def get_majorticklabels(self):
#    1464     """Return this Axis' major tick labels, as a list of `~.text.Text`."""
# -> 1465     self._update_ticks()
#    1466     ticks = self.get_major_ticks()
#    1467     labels1 = [tick.label1 for tick in ticks if tick.label1.get_visible()]
#
# File /opt/anaconda3/envs/windForecast/lib/python3.10/site-packages/matplotlib/axis.py:1294, in Axis._update_ticks(self)
#    1292 major_locs = self.get_majorticklocs()
#    1293 major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1294 major_ticks = self.get_major_ticks(len(major_locs))
#    1295 for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#    1296     tick.update_position(loc)
#
# File /opt/anaconda3/envs/windForecast/lib/python3.10/site-packages/matplotlib/axis.py:1675, in Axis.get_major_ticks(self, numticks)
#    1671     numticks = len(self.get_majorticklocs())
#    1673 while len(self.majorTicks) < numticks:
#    1674     # Update the new tick label properties from the old.
# -> 1675     tick = self._get_tick(major=True)
#    1676     self.majorTicks.append(tick)
#    1677     self._copy_tick_props(self.majorTicks[0], tick)
#
# File /opt/anaconda3/envs/windForecast/lib/python3.10/site-packages/matplotlib/axis.py:1603, in Axis._get_tick(self, major)
#    1599     raise NotImplementedError(
#    1600         f"The Axis subclass {self.__class__.__name__} must define "
#    1601         "_tick_class or reimplement _get_tick()")
#    1602 tick_kw = self._major_tick_kw if major else self._minor_tick_kw
# -> 1603 return self._tick_class(self.axes, 0, major=major, **tick_kw)
#
# File /opt/anaconda3/envs/windForecast/lib/python3.10/site-packages/matplotlib/axis.py:371, in XTick.__init__(self, *args, **kwargs)
#     369 # x in data coords, y in axes coords
#     370 ax = self.axes
# --> 371 self.tick1line.set(
#     372     data=([0], [0]), transform=ax.get_xaxis_transform("tick1"))
#     373 self.tick2line.set(
#     374     data=([0], [1]), transform=ax.get_xaxis_transform("tick2"))
#     375 self.gridline.set(
#     376     data=([0, 0], [0, 1]), transform=ax.get_xaxis_transform("grid"))
#
# File /opt/anaconda3/envs/windForecast/lib/python3.10/site-packages/matplotlib/artist.py:146, in Artist.__init_subclass__.<locals>.<lambda>(self, **kwargs)
#     138 if not hasattr(cls.set, '_autogenerated_signature'):
#     139     # Don't overwrite cls.set if the subclass or one of its parents
#     140     # has defined a set method set itself.
#     141     # If there was no explicit definition, cls.set is inherited from
#     142     # the hierarchy of auto-generated set methods, which hold the
#     143     # flag _autogenerated_signature.
#     144     return
# --> 146 cls.set = lambda self, **kwargs: Artist.set(self, **kwargs)
#     147 cls.set.__name__ = "set"
#     148 cls.set.__qualname__ = f"{cls.__qualname__}.set"
#
# File /opt/anaconda3/envs/windForecast/lib/python3.10/site-packages/matplotlib/artist.py:1241, in Artist.set(self, **kwargs)
#    1237 def set(self, **kwargs):
#    1238     # docstring and signature are auto-generated via
#    1239     # Artist._update_set_signature_and_docstring() at the end of the
#    1240     # module.
# -> 1241     return self._internal_update(cbook.normalize_kwargs(kwargs, self))
#
# File /opt/anaconda3/envs/windForecast/lib/python3.10/site-packages/matplotlib/artist.py:1233, in Artist._internal_update(self, kwargs)
#    1226 def _internal_update(self, kwargs):
#    1227     """
#    1228     Update artist properties without prenormalizing them, but generating
#    1229     errors as if calling `set`.
#    1230
#    1231     The lack of prenormalization is to maintain backcompatibility.
#    1232     """
# -> 1233     return self._update_props(
#    1234         kwargs, "{cls.__name__}.set() got an unexpected keyword argument "
#    1235         "{prop_name!r}")
#
# File /opt/anaconda3/envs/windForecast/lib/python3.10/site-packages/matplotlib/artist.py:1209, in Artist._update_props(self, props, errfmt)
#    1205             if not callable(func):
#    1206                 raise AttributeError(
#    1207                     errfmt.format(cls=type(self), prop_name=k),
#    1208                     name=k)
# -> 1209             ret.append(func(v))
#    1210 if ret:
#    1211     self.pchanged()
#
# File /opt/anaconda3/envs/windForecast/lib/python3.10/site-packages/matplotlib/lines.py:742, in Line2D.set_transform(self, t)
#     740 self._invalidx = True
#     741 self._invalidy = True
# --> 742 super().set_transform(t)
#
# File /opt/anaconda3/envs/windForecast/lib/python3.10/site-packages/matplotlib/artist.py:445, in Artist.set_transform(self, t)
#     443 self._transform = t
#     444 self._transformSet = True
# --> 445 self.pchanged()
#     446 self.stale = True
#
# File /opt/anaconda3/envs/windForecast/lib/python3.10/site-packages/matplotlib/artist.py:425, in Artist.pchanged(self)
#     414 def pchanged(self):
#     415     """
#     416     Call all of the registered callbacks.
#     417
#    (...)
#     423     remove_callback
#     424     """
# --> 425     self._callbacks.process("pchanged")
#
# File /opt/anaconda3/envs/windForecast/lib/python3.10/site-packages/matplotlib/cbook.py:357, in CallbackRegistry.process(self, s, *args, **kwargs)
#     355 if self._signals is not None:
#     356     _api.check_in_list(self._signals, signal=s)
# --> 357 for ref in list(self.callbacks.get(s, {}).values()):
#     358     func = ref()
#     359     if func is not None:
#
# KeyboardInterrupt:
